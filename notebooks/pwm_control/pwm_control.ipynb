# %% [markdown]
# # Room Temperature Control with PWM Controller
# Simulating room temperature control with a PWM controller in heating mode. You can modify model parameters and then press the 'submit' button to see their effect.<br>
# Note that at 6 h the set point is lowered with 3 K and at 12 h the set point is restored to its original value.

# %%
# %matplotlib inline
import dependencies
from IPython.display import display
from pwm_control import gui
display(gui)
